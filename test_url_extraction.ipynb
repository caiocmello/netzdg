# %% [markdown]
# <a href="https://colab.research.google.com/github/caiocmello/netzdg/blob/main/test_url_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('tweets_NetzDG.csv')

# %%
df.head()
# Out:
#               tweet_id user_username  \
# 0  1002588519561334784    mhansen134
# 1  1002587919704616965  LoveSpeechDE
# 2  1002587788380864513  LoveSpeechDE
# 3  1002583081176522754   Maggielein_
# 4  1002580970933977088  HuberJoachim
#
#                                                 text               source  \
# 0  @GameCraftOP @balzer_sascha @Dicker_Wikinger K...   Twitter Web Client
# 1  RT @hwieduwilt Kluger Text über das entgrenzte...   Twitter for iPhone
# 2  „Organisierten #Hass verbreiten“ ❤️ #IB #Ident...   Twitter for iPhone
# 3  @maxotte_says Hier wird alles "Gute" an Gesetz...  Twitter for Android
# 4  Kaum Beschwerden über das Löschregiment: Macht...   Twitter for iPhone
#
#        conversation_id           author_id                created_at  \
# 0  1002581170910097408          2782971553  2018-06-01T16:31:44.000Z
# 1  1002587919704616965  762354289973026816  2018-06-01T16:29:21.000Z
# 2  1002587788380864513  762354289973026816  2018-06-01T16:28:50.000Z
# ...

# %%
df = df[['tweet_id', 'user_username', 'text']]

# %%
df.head()
# Out:
#               tweet_id user_username  \
# 0  1002588519561334784    mhansen134
# 1  1002587919704616965  LoveSpeechDE
# 2  1002587788380864513  LoveSpeechDE
# 3  1002583081176522754   Maggielein_
# 4  1002580970933977088  HuberJoachim
#
#                                                 text
# 0  @GameCraftOP @balzer_sascha @Dicker_Wikinger K...
# 1  RT @hwieduwilt Kluger Text über das entgrenzte...
# 2  „Organisierten #Hass verbreiten“ ❤️ #IB #Ident...
# 3  @maxotte_says Hier wird alles "Gute" an Gesetz...
# 4  Kaum Beschwerden über das Löschregiment: Macht...

# %%
# prompt: if there is a url in column text, write this url in a new colum called url

import re
def extract_url(text):
  url = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', text)
  if url:
    return url[0]
  else:
    return None
df['url'] = df['text'].apply(extract_url)
df.head()
# Out:
#               tweet_id user_username  \
# 0  1002588519561334784    mhansen134
# 1  1002587919704616965  LoveSpeechDE
# 2  1002587788380864513  LoveSpeechDE
# 3  1002583081176522754   Maggielein_
# 4  1002580970933977088  HuberJoachim
#
#                                                 text                      url
# 0  @GameCraftOP @balzer_sascha @Dicker_Wikinger K...  https://t.co/UEqp15q2RE
# 1  RT @hwieduwilt Kluger Text über das entgrenzte...  https://t.co/yU5oMQx5mR
# 2  „Organisierten #Hass verbreiten“ ❤️ #IB #Ident...  https://t.co/VKDGnFQdce
# 3  @maxotte_says Hier wird alles "Gute" an Gesetz...                     None
# 4  Kaum Beschwerden über das Löschregiment: Macht...  https://t.co/Bl9oFNCbvt

# %%
# prompt: if text in column text starts with RT, create a new dataframe with this lines

df_rt = df[df['text'].str.startswith('RT')]

# %%
df_rt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 267573 entries, 1 to 391541
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       267573 non-null  int64
#  1   user_username  267573 non-null  object
#  2   text           267573 non-null  object
#  3   url            200019 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 10.2+ MB

# %%
# prompt: remove duplicates in column text

df.drop_duplicates(subset='text', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152736 entries, 0 to 391547
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       152736 non-null  int64
#  1   user_username  152736 non-null  object
#  2   text           152736 non-null  object
#  3   url            84900 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 5.8+ MB

# %%
df.head()
# Out:
#               tweet_id user_username  \
# 0  1002588519561334784    mhansen134
# 1  1002587919704616965  LoveSpeechDE
# 2  1002587788380864513  LoveSpeechDE
# 3  1002583081176522754   Maggielein_
# 4  1002580970933977088  HuberJoachim
#
#                                                 text                      url
# 0  @GameCraftOP @balzer_sascha @Dicker_Wikinger K...  https://t.co/UEqp15q2RE
# 1  RT @hwieduwilt Kluger Text über das entgrenzte...  https://t.co/yU5oMQx5mR
# 2  „Organisierten #Hass verbreiten“ ❤️ #IB #Ident...  https://t.co/VKDGnFQdce
# 3  @maxotte_says Hier wird alles "Gute" an Gesetz...                     None
# 4  Kaum Beschwerden über das Löschregiment: Macht...  https://t.co/Bl9oFNCbvt

# %%
# prompt: if text in column text starts with RT, delete line in dataset

df = df[~df['text'].str.startswith('RT')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 122839 entries, 0 to 391547
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       122839 non-null  int64
#  1   user_username  122839 non-null  object
#  2   text           122839 non-null  object
#  3   url            64395 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 4.7+ MB

# %%
df
# Out:
#                    tweet_id user_username  \
# 0       1002588519561334784    mhansen134
# 2       1002587788380864513  LoveSpeechDE
# 3       1002583081176522754   Maggielein_
# 4       1002580970933977088  HuberJoachim
# 5       1002577890247143431       ESchmok
# ...                     ...           ...
# 391543   999156683384467457     safe_ID35
# 391544   999156413002911744     safe_ID35
# 391545   999155933119942656     safe_ID35
# 391546   999117500297170945     m3_ememem
# 391547   999108371516141568   Maggielein_
#
#                                                      text  \
# 0       @GameCraftOP @balzer_sascha @Dicker_Wikinger K...
# 2       „Organisierten #Hass verbreiten“ ❤️ #IB #Ident...
# 3       @maxotte_says Hier wird alles "Gute" an Gesetz...
# 4       Kaum Beschwerden über das Löschregiment: Macht...
# 5       @mtz767 @Reconquista1099 @Martin_Sellner Diese...
# ...                                                   ...
# ...

# %%
df1 = df[:6000]
df2 = df[6000:12000]
df3 = df[12000:18000]
df4 = df[18000:24000]
df5 = df[24000:30000]
df6 = df[30000:36000]
df7 = df[36000:42000]
df8 = df[42000:48000]
df9 = df[48000:54000]
df10 = df[54000:60000]
df11 = df[60000:66000]
df12 = df[66000:72000]
df13 = df[72000:78000]
df14 = df[78000:84000]
df15 = df[84000:90000]
df16 = df[90000:96000]
df17 = df[96000:102000]
df18 = df[102000:108000]
df19 = df[108000:114000]
df20 = df[114000:120000]
df21 = df[120000:]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 122839 entries, 0 to 391547
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       122839 non-null  int64
#  1   user_username  122839 non-null  object
#  2   text           122839 non-null  object
#  3   url            64395 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 4.7+ MB

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df8
# Out:
#                    tweet_id    user_username  \
# 119658  1471475238345060355      julian__dng
# 119659  1471471933241843717  na_presseportal
# 119660  1471459286358405123   raumfunkstelle
# 119662  1471455916671512577  MartinAnanthar1
# 119663  1471454307379781634          mtaushb
# ...                     ...              ...
# 141523  1539702478723219457         _YugiYT_
# 141525  1539678344052035584         dcolgren
# 141526  1539657271239532545        Knopp1776
# 141528  1539645538831945733        metronaut
# 141529  1539632050273148928    Borussenvogel
#
#                                                      text  \
# 119658  @J8T4K Natürlich geht es nicht in Ordnung, was...
# 119659  AfD - Alternative für Deutschland: Joachim Pau...
# 119660  @JakobFelser Wenn das Bundesjustizministerium ...
# 119662  @Anwalt_Jun Auch nachdem ich viel aus ihrem ex...
# 119663  @CatrinaCavalera So ist es. Und beim NetzDG ge...
# ...                                                   ...
# ...

# %%
# prompt: how to get the full original url for this shortned version 'https://t.co/UEqp15q2RE'
from tqdm import tqdm
import requests

tqdm.pandas()

def get_original_url(short_url):
  try:
    response = requests.head(short_url, allow_redirects=True)
    return response.url
  except:
    return None
dataframe = df8
dataframe['original_url'] = dataframe['url'].progress_apply(get_original_url)
dataframe.head()

dataframe.to_csv('/content/drive/MyDrive/df8.csv', index=False)
# Out:
#  17%|█▋        | 1029/6000 [04:05<25:50,  3.21it/s]

# %%
df1.to_csv('df1.csv', index=False)

# %%
# prompt: save data in google drive

from google.colab import drive
drive.mount('/content/drive')

df1.to_csv('/content/drive/My Drive/df1.csv', index=False)
